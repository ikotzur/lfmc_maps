# %% [markdown]
# # LFMC Mapping Tool

# %% [markdown]
# ### Enter the csv path and column names (lat, lon and date) of observations to predict LFMC for each row of csv. Also enter an output path to return the input with prediciton columns appended

# %%
csv_path = '../inputs/input.csv'
lat_col = 'Location_Latitude'
lon_col = 'Location_Longitude'
date_col = 'Collection_Date_YYYY-MM-DD'

csv_out_path = '../output_fmc_predictions.csv'

# %% [markdown]
# ### To produce LFMC observations for good quality Sentinel-2 satellite data within 6 days before or after observations, in the above dropdown menu 'Run', click 'Run All Cells'
# In the ouput csv, as well as the prediction nearest in space and time ('fmc_center'), there is a sequence of 9 values representing the nearest 3x3 pixels ('fmc_patch'), and the time of the Sentinel-2 observation used for prediction ('fmc_sentinel_time'). Running modelling may take a few minutes or more depending number of observations.

# %%
import pandas as pd
import xarray as xr
import rioxarray
import numpy as np
from pyproj import Transformer
import datetime
import joblib
import os
import dask.distributed
from pystac_client import Client
from odc.stac import configure_rio, stac_load
from datetime import timedelta
import matplotlib.pyplot as plt
import shapely.geometry as geom


# # def compute_fmc_from_csv(csv_path, lat_col='lat', lon_col='lon', date_col='date'):
#     # """
#     # Given a CSV of coordinates and dates, retrieve LFMC for each point.
#     # Only uses Sentinel-2 images within ±6 days of the observation date.
#     # Returns dataframe with:
#     #   - 'fmc_center': LFMC of closest pixel
#     #   - 'fmc_patch': list of LFMC values in 9x9 patch
#     # """

df = pd.read_csv(csv_path)

configure_rio(cloud_defaults=True, aws={"aws_unsigned": True})

# Load RF model
rf = joblib.load('../inputs/rf_s2fmc_forest.joblib')

# STAC catalog
catalog = Client.open("https://explorer.dea.ga.gov.au/stac")

# EPSG:4326 transformer (we’ll only use this for bbox definition)
# Note: your CSV is already lat/lon (EPSG:4326), so no transform needed
edge_deg = 60 / 111320.0  # ~60 m in degrees at equator (rough approximation)

# Coordinate transformer
transformer = Transformer.from_crs("EPSG:4326", "EPSG:3577", always_xy=True)

cache = {}
fmc_center_list = []
fmc_patch_list = []
fmc_sentinel_time_list = []

for idx, row in df.iloc[:,:].iterrows():
    lat, lon, obs_date = row[lat_col], row[lon_col], pd.to_datetime(row[date_col])
    key = (lat, lon, obs_date)

    if key in cache:
        fmc_center_list.append(cache[key]['center'])
        fmc_patch_list.append(cache[key]['patch'])
        fmc_sentinel_time_list.append(cache[key]['sentinel_time'])
        continue

    # Define small 60 m bbox directly in EPSG:4326
    min_lon, max_lon = lon - edge_deg/2, lon + edge_deg/2
    min_lat, max_lat = lat - edge_deg/2, lat + edge_deg/2

    # Query STAC for ±6 days
    start_date = (obs_date - pd.Timedelta(days=6)).strftime('%Y-%m-%d')
    end_date = (obs_date + pd.Timedelta(days=6)).strftime('%Y-%m-%d')

    query = catalog.search(
        collections=["ga_s2am_ard_3", "ga_s2bm_ard_3", "ga_s2cm_ard_3"],
        datetime=(start_date, end_date),
        bbox=(min_lon, min_lat, max_lon, max_lat)
    )
    
    items = list(query.items())
    if len(items) == 0:
        print('Query returned no data for',key)
        fmc_center_list.append(np.nan)
        fmc_patch_list.append([np.nan]*9)  # 3x3 patch
        fmc_sentinel_time.append(np.nan)
        cache[key] = {'center': np.nan, 'patch': [np.nan]*9, 'sentinel_time': np.nan}
        continue
    print('Query did return data for',key)
    
    # Sentinel-2 bands
    s2_bands = [
        'nbart_red', 'nbart_green', 'nbart_blue',
        'nbart_red_edge_1', 'nbart_red_edge_2', 'nbart_red_edge_3',
        'nbart_nir_1', 'nbart_nir_2',
        'nbart_swir_2', 'nbart_swir_3'
    ]

    # Make bbox polygon for loading (in EPSG:4326)
    bbox_poly = geom.box(min_lon, min_lat, max_lon, max_lat)

    # Load only the 3x3 window, reproject to EPSG:3577
    s2_cube = stac_load(
        items,
        bands=s2_bands + ['oa_fmask'],
        chunks={'time': 1},
        groupby="solar_day",
        cloud_mask='fmask',
        crs="EPSG:3577",         # <-- reprojection happens here
        resolution=20,
        geopolygon=bbox_poly     # <-- crop to tiny bbox
    )

    # Convert lat, lon to projected coordinates (EPSG:3577)
    x, y = transformer.transform(lon, lat)

    # Make sure only 3x3 pixels around lon/lat returned
    s2_cube = s2_cube.sel(y=slice(y+30,y-30),x=slice(x-30,x+30))
    
    s2_cube = s2_cube.where(s2_cube['oa_fmask'] == 1).drop_vars('oa_fmask').dropna(dim='time', how='all')
    s2_cube.load()
    
    if len(s2_cube.time) == 0:
        print('Masking removed all data for',key)
        fmc_center_list.append(np.nan)
        fmc_patch_list.append([np.nan]*81)
        fmc_sentinel_time_list.append(np.nan)
        cache[key] = {'center': np.nan, 'patch': [np.nan]*81, 'sentinel_time':np.nan}
        continue
    
    s2_cube['ndii'] = (s2_cube.nbart_nir_1 - s2_cube.nbart_swir_2) / (s2_cube.nbart_nir_1 + s2_cube.nbart_swir_2)
    s2_cube['ndvi'] = (s2_cube.nbart_nir_1 - s2_cube.nbart_red) / (s2_cube.nbart_nir_1 + s2_cube.nbart_red)

    # s2_cube['ndvi'].plot(col='time',col_wrap=3); plt.show()

    # Select closest in time to obs
    s2_cube = s2_cube.sel(time=obs_date, method='nearest')
    t = pd.to_datetime(s2_cube.time.values)
    
    data_df = s2_cube[rf.feature_names_in_].drop_vars(['spatial_ref', 'time']).to_dataframe().dropna()
    if data_df.empty:
        fmc_center_list.append(np.nan)
        fmc_patch_list.append([np.nan]*81)
        fmc_sentinel_time_list.append(np.nan)
        cache[key] = {'center': np.nan, 'patch': [np.nan]*81, 'sentinel_time':np.nan}
        continue
    
    preds = rf.predict(data_df)
    
    # Convert predictions to 2D xarray
    # fmc_array = np.full((len(s2_cube.y), len(s2_cube.x)), np.nan)
    # fmc_array.ravel()[data_df.index.codes[0]] = preds
    data_df['fmc'] = preds
    s2_cube_pred = data_df.to_xarray()

    # s2_cube_pred['fmc'].plot(); plt.show()
    
    # Closest pixel
    # x_idx = np.abs(s2_cube.x - x).argmin().item()
    # y_idx = np.abs(s2_cube.y - y).argmin().item()
    # fmc_center = fmc_array[y_idx, x_idx]
    fmc_center = s2_cube_pred.sel(y=y, x=x, method='nearest')['fmc'].values
    
#     # 9x9 patch
#     patch = fmc_array[max(0, y_idx-4):y_idx+5, max(0, x_idx-4):x_idx+5].flatten()
    
    fmc_center_list.append(fmc_center)
    fmc_patch_list.append(preds.tolist())
    fmc_sentinel_time_list.append(t)
    cache[key] = {'center': fmc_center, 'patch': preds.tolist(), 'sentinel_time': t}
    

df['fmc_center'] = fmc_center_list
df['fmc_center'] = df['fmc_center'].astype('float32')
df['fmc_patch'] = fmc_patch_list
df['fmc_sentinel_time'] = fmc_sentinel_time_list
    
    # return df

df.to_csv(csv_out_path)
# Out:
# Query did return data for (-29.6199439, 153.2933406, Timestamp('2021-04-12 00:00:00'))
# Query did return data for (-29.81746551, 153.2574998, Timestamp('2021-04-15 00:00:00'))
# Query did return data for (-29.6199439, 153.2933406, Timestamp('2021-05-03 00:00:00'))
# Masking removed all data for (-29.6199439, 153.2933406, Timestamp('2021-05-03 00:00:00'))
# Query did return data for (-29.81746551, 153.2574998, Timestamp('2021-05-03 00:00:00'))
# Masking removed all data for (-29.81746551, 153.2574998, Timestamp('2021-05-03 00:00:00'))
# Query did return data for (-29.81746551, 153.2574998, Timestamp('2021-05-31 00:00:00'))
# Query did return data for (-29.6199439, 153.2933406, Timestamp('2021-05-31 00:00:00'))
# Query did return data for (-29.6199439, 153.2933406, Timestamp('2021-06-30 00:00:00'))
# Query did return data for (-29.81746551, 153.2574998, Timestamp('2021-06-30 00:00:00'))
# Query did return data for (-29.6199439, 153.2933406, Timestamp('2021-11-10 00:00:00'))
# Query did return data for (-30.42408349, 153.043227, Timestamp('2021-11-25 00:00:00'))
# Masking removed all data for (-30.42408349, 153.043227, Timestamp('2021-11-25 00:00:00'))
# Query did return data for (-29.223285, 153.3669609, Timestamp('2021-12-14 00:00:00'))
# Query did return data for (-29.62118897, 153.3065918, Timestamp('2021-12-19 00:00:00'))
# Query did return data for (-29.81746551, 153.2574998, Timestamp('2021-12-20 00:00:00'))
# Query did return data for (-30.92674254, 153.052853, Timestamp('2021-12-21 00:00:00'))
# Query did return data for (-29.22403665, 153.3669323, Timestamp('2022-01-17 00:00:00'))
# Masking removed all data for (-29.22403665, 153.3669323, Timestamp('2022-01-17 00:00:00'))
# Query did return data for (-29.62021564, 153.2953809, Timestamp('2022-01-31 00:00:00'))
# Query did return data for (-29.8174413, 153.2574982, Timestamp('2022-02-01 00:00:00'))
# Query did return data for (-30.60584089, 152.9844993, Timestamp('2022-02-01 00:00:00'))
# Query did return data for (-29.22395005, 153.3667462, Timestamp('2022-02-15 00:00:00'))
# Query did return data for (-30.42346866, 153.043276, Timestamp('2022-02-21 00:00:00'))
# Query did return data for (-29.62117805, 153.3066435, Timestamp('2022-02-22 00:00:00'))
# Query did return data for (-29.22399187, 153.3666721, Timestamp('2022-04-20 00:00:00'))
# Masking removed all data for (-29.22399187, 153.3666721, Timestamp('2022-04-20 00:00:00'))
# Query did return data for (-29.62017832, 153.2953544, Timestamp('2022-06-01 00:00:00'))
# Query did return data for (-29.81746025, 153.2575232, Timestamp('2022-06-01 00:00:00'))
# Query did return data for (-30.34710293, 153.0921499, Timestamp('2022-06-13 00:00:00'))
# Query did return data for (-30.42394716, 153.0432583, Timestamp('2022-06-14 00:00:00'))
# Query did return data for (-29.22395931, 153.3669316, Timestamp('2022-06-15 00:00:00'))
# Query did return data for (-29.22400416, 153.3667332, Timestamp('2022-07-18 00:00:00'))
# Query did return data for (-29.62023169, 153.2954046, Timestamp('2022-07-28 00:00:00'))
# Query did return data for (-29.81743738, 153.2575137, Timestamp('2022-07-28 00:00:00'))
# Query did return data for (-29.22398525, 153.3669548, Timestamp('2022-08-15 00:00:00'))
# Query did return data for (-29.81743815, 153.2575223, Timestamp('2022-09-07 00:00:00'))
# Query did return data for (-29.62023604, 153.2953952, Timestamp('2022-09-07 00:00:00'))
# Query did return data for (-29.62022548, 153.2953846, Timestamp('2022-10-30 00:00:00'))
# Query did return data for (-29.81745957, 153.2575113, Timestamp('2022-10-31 00:00:00'))
# Query did return data for (-29.8175, 153.2575, Timestamp('2022-12-14 00:00:00'))
# Query did return data for (-29.224, 153.3669, Timestamp('2022-12-20 00:00:00'))
# Query did return data for (-29.81746173, 153.2574874, Timestamp('2023-01-17 00:00:00'))
# Query did return data for (-29.6212097, 153.3067279, Timestamp('2023-01-18 00:00:00'))
# Query did return data for (-29.62118588, 153.3066475, Timestamp('2023-02-06 00:00:00'))
# Query did return data for (-29.81745165, 153.2574972, Timestamp('2023-02-07 00:00:00'))
# Query did return data for (-29.22394567, 153.3666688, Timestamp('2023-03-15 00:00:00'))
# Query did return data for (-29.62023477, 153.2954137, Timestamp('2023-03-22 00:00:00'))
# Query did return data for (-29.81746543, 153.2575183, Timestamp('2023-03-23 00:00:00'))
# Masking removed all data for (-29.81746543, 153.2575183, Timestamp('2023-03-23 00:00:00'))
# Query did return data for (-30.92673137, 153.0529401, Timestamp('2023-03-27 00:00:00'))
# Query did return data for (-29.22398571, 153.366744, Timestamp('2023-04-18 00:00:00'))
# Masking removed all data for (-29.22398571, 153.366744, Timestamp('2023-04-18 00:00:00'))
# Query did return data for (-29.62027163, 153.2953429, Timestamp('2023-07-10 00:00:00'))
# Query did return data for (-29.81744729, 153.2575181, Timestamp('2023-07-10 00:00:00'))
# Query did return data for (-29.62131644, 153.3068122, Timestamp('2024-03-12 00:00:00'))
# Query did return data for (-29.81753351, 153.257533, Timestamp('2024-03-13 00:00:00'))
# Query did return data for (-29.6212147, 153.3067299, Timestamp('2024-04-03 00:00:00'))
# Query did return data for (-29.81744736, 153.2575242, Timestamp('2024-04-03 00:00:00'))
# Query did return data for (-29.62114637, 153.3066061, Timestamp('2024-05-22 00:00:00'))
# Query did return data for (-29.81702048, 153.2579475, Timestamp('2024-05-22 00:00:00'))
# Query did return data for (-29.62118299, 153.3066504, Timestamp('2024-07-16 00:00:00'))
# Query did return data for (-29.81745148, 153.2575196, Timestamp('2024-07-16 00:00:00'))
# Query did return data for (-29.62130123, 153.3067975, Timestamp('2024-08-19 00:00:00'))
# Query did return data for (-29.81702107, 153.2579888, Timestamp('2024-08-20 00:00:00'))
# Query did return data for (-27.33026, 152.791715, Timestamp('2024-08-21 00:00:00'))
# Query did return data for (-27.5175, 153.1505555, Timestamp('2024-08-21 00:00:00'))
# Query did return data for (-26.366943, 152.891143, Timestamp('2024-08-21 00:00:00'))
# Query did return data for (-26.367104, 152.891133, Timestamp('2024-08-21 00:00:00'))
# Query did return data for (-26.367141, 152.891115, Timestamp('2024-08-21 00:00:00'))
# Query did return data for (-26.367239, 152.890894, Timestamp('2024-08-21 00:00:00'))
# Query did return data for (-26.367289, 152.89089, Timestamp('2024-08-21 00:00:00'))
# Query did return data for (-26.367063, 152.891039, Timestamp('2024-08-21 00:00:00'))
# Query did return data for (-27.50786306, 152.7822235, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.400641, 152.777298, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.5741904, 153.1810761, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.57431122, 153.1810045, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.50766549, 152.7823185, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.50794225, 152.7821631, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.5741968, 153.1768972, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.4990371, 152.8119221, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.5739387, 153.176923, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.33557354, 153.0278909, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.50801464, 152.7821319, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.62895848, 153.0836656, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.37540195, 152.9953908, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.57437861, 153.1810213, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.62882581, 153.0836896, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.49896566, 152.8119355, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.3752698, 152.9953633, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.37547855, 152.9953982, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.57385899, 153.1769452, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.49911718, 152.8118897, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.57378293, 153.1769577, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.33537196, 153.0278691, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.33532435, 153.0278767, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.57394268, 153.1811178, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.63660666, 153.0872803, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.6371763, 153.0871343, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.3749762, 152.9952939, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.33525076, 153.0278677, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.50755305, 152.7823995, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.57401392, 153.1811074, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.49887385, 152.811963, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.49878631, 152.8119972, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.63677434, 153.0872504, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.33547969, 153.0278899, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.50777377, 152.7822969, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.33552466, 153.0278863, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.57414262, 153.176921, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.4992471, 152.811873, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.62921755, 153.083572, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.62907921, 153.0836297, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.57405639, 153.1769166, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.57411224, 153.1810971, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.37557466, 152.9954202, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.37512312, 152.9953239, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.57422578, 153.1768911, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.57386446, 153.1769527, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.63706744, 153.0871824, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.63698132, 153.0872024, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.6291616, 153.0836013, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.57411056, 153.1810935, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.62875762, 153.0836847, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.636885, 153.0872068, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.5743793, 153.1810146, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.50801516, 152.7821276, Timestamp('2024-08-22 00:00:00'))
# Query did return data for (-27.805413, 153.348562, Timestamp('2024-09-05 00:00:00'))
# Query did return data for (-27.811092, 153.358865, Timestamp('2024-09-05 00:00:00'))
# Query did return data for (-27.805314, 153.348572, Timestamp('2024-09-05 00:00:00'))
# Query did return data for (-27.811273, 153.358856, Timestamp('2024-09-05 00:00:00'))
# Query did return data for (-27.805133, 153.348582, Timestamp('2024-09-05 00:00:00'))
# Query did return data for (-27.811444, 153.358846, Timestamp('2024-09-05 00:00:00'))
# Query did return data for (-26.376625, 152.997721, Timestamp('2024-09-10 00:00:00'))
# Query did return data for (-26.367279, 152.891, Timestamp('2024-09-10 00:00:00'))
# Query did return data for (-26.366924, 152.891247, Timestamp('2024-09-10 00:00:00'))
# Query did return data for (-26.366991, 152.891091, Timestamp('2024-09-10 00:00:00'))
# Query did return data for (-26.376596, 152.997442, Timestamp('2024-09-10 00:00:00'))
# Query did return data for (-26.366956, 152.891165, Timestamp('2024-09-10 00:00:00'))
# Query did return data for (-26.376567, 152.997394, Timestamp('2024-09-10 00:00:00'))
# Query did return data for (-26.376613, 152.997612, Timestamp('2024-09-10 00:00:00'))
# Query did return data for (-26.367204, 152.89094, Timestamp('2024-09-10 00:00:00'))
# Query did return data for (-26.367116, 152.890929, Timestamp('2024-09-10 00:00:00'))
# Query did return data for (-26.376598, 152.997565, Timestamp('2024-09-10 00:00:00'))
# Query did return data for (-26.376463, 152.997319, Timestamp('2024-09-10 00:00:00'))
# Query did return data for (-27.5175, 153.1505555, Timestamp('2024-09-16 00:00:00'))
# Query did return data for (-27.33026, 152.791715, Timestamp('2024-09-21 00:00:00'))
# Query did return data for (-27.400641, 152.777298, Timestamp('2024-09-22 00:00:00'))
# Query did return data for (-27.400641, 152.777298, Timestamp('2024-10-20 00:00:00'))
# Query did return data for (-26.366924, 152.891247, Timestamp('2024-10-20 00:00:00'))
# Query did return data for (-27.5175, 153.1505555, Timestamp('2024-10-20 00:00:00'))
# Query did return data for (-26.367116, 152.890929, Timestamp('2024-10-20 00:00:00'))
# Query did return data for (-26.367289, 152.89089, Timestamp('2024-10-20 00:00:00'))
# Query did return data for (-26.367104, 152.891133, Timestamp('2024-10-20 00:00:00'))
# Query did return data for (-26.367204, 152.89094, Timestamp('2024-10-20 00:00:00'))
# Query did return data for (-26.367279, 152.891, Timestamp('2024-10-20 00:00:00'))
# Query did return data for (-26.366991, 152.891091, Timestamp('2024-10-20 00:00:00'))
# Query did return data for (-26.367141, 152.891115, Timestamp('2024-10-20 00:00:00'))
# Query did return data for (-26.367063, 152.891039, Timestamp('2024-10-20 00:00:00'))
# Query did return data for (-26.367239, 152.890894, Timestamp('2024-10-20 00:00:00'))
# Query did return data for (-26.366943, 152.891143, Timestamp('2024-10-20 00:00:00'))
# Query did return data for (-27.805133, 153.348582, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-26.376613, 152.997612, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-26.376596, 152.997442, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-27.805413, 153.348562, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-27.811092, 153.358865, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-27.811273, 153.358856, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-27.811444, 153.358846, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-26.376598, 152.997565, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-27.805224, 153.348572, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-26.376567, 152.997394, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-27.811182, 153.358866, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-27.811444, 153.358836, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-26.376463, 152.997319, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-27.805494, 153.348552, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-26.376625, 152.997721, Timestamp('2024-10-21 00:00:00'))
# Query did return data for (-29.62122534, 153.3067778, Timestamp('2024-10-23 00:00:00'))
# Query did return data for (-29.81747692, 153.2574994, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-19.2024, 146.59204, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-19.2, 146.592, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-19.20214, 146.59214, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-19.20221, 146.59211, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-19.20222, 146.5921, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-19.1, 146.324, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-19.20199, 146.59238, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-19.102, 146.324, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-19.20251, 146.59196, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-19.20213, 146.59214, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-19.20222, 146.59211, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-19.20242, 146.59205, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-19.20247, 146.59222, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-19.20248, 146.59203, Timestamp('2024-10-24 00:00:00'))
# Query did return data for (-27.33026, 152.791715, Timestamp('2024-10-25 00:00:00'))
# Query did return data for (-27.513, 153.453, Timestamp('2024-11-25 00:00:00'))
# Query did return data for (-27.523, 153.455, Timestamp('2024-11-25 00:00:00'))
# Query did return data for (-27.516, 153.441, Timestamp('2024-11-25 00:00:00'))
# Masking removed all data for (-27.516, 153.441, Timestamp('2024-11-25 00:00:00'))
# Query did return data for (-29.8170424, 153.2580228, Timestamp('2025-01-02 00:00:00'))
# Query did return data for (-29.6211794, 153.3067337, Timestamp('2025-02-18 00:00:00'))
# Query did return data for (-29.81741996, 153.2574803, Timestamp('2025-02-18 00:00:00'))
# Query did return data for (-33.8481, 149.7995, Timestamp('2025-02-26 00:00:00'))
# Query did return data for (-33.8987, 149.6027, Timestamp('2025-02-26 00:00:00'))
# Query did return data for (-33.8987, 149.60235, Timestamp('2025-02-26 00:00:00'))
# Query did return data for (-33.848, 149.7993, Timestamp('2025-02-26 00:00:00'))
# Query did return data for (-33.8481, 149.7998, Timestamp('2025-02-26 00:00:00'))
# Query did return data for (-33.8481, 149.7996, Timestamp('2025-02-26 00:00:00'))
# Query did return data for (-33.89869058, 149.602, Timestamp('2025-02-26 00:00:00'))
# Query did return data for (-33.848, 149.7994, Timestamp('2025-02-26 00:00:00'))
# Query did return data for (-33.8479, 149.7991, Timestamp('2025-02-26 00:00:00'))
# Query did return data for (-33.8987, 149.6025, Timestamp('2025-02-26 00:00:00'))
# Query did return data for (-33.8987, 149.6026, Timestamp('2025-02-26 00:00:00'))
# Query did return data for (-33.8987, 149.6023, Timestamp('2025-02-26 00:00:00'))
# Query did return data for (-33.3976, 148.9675, Timestamp('2025-03-03 00:00:00'))
# Query did return data for (-33.3976, 148.9677, Timestamp('2025-03-03 00:00:00'))
# Query did return data for (-33.3975, 148.967965, Timestamp('2025-03-03 00:00:00'))
# Query did return data for (-33.3976, 148.9682, Timestamp('2025-03-03 00:00:00'))
# Query did return data for (-33.3976, 148.9684, Timestamp('2025-03-03 00:00:00'))
# Query did return data for (-33.3975, 148.9684, Timestamp('2025-03-03 00:00:00'))
# Query did return data for (-35.189383, 148.409785, Timestamp('2025-03-24 00:00:00'))
# Query did return data for (-35.189443, 148.409902, Timestamp('2025-03-24 00:00:00'))
# Query did return data for (-35.189533, 148.410004, Timestamp('2025-03-24 00:00:00'))
# Query did return data for (-35.189287, 148.409745, Timestamp('2025-03-24 00:00:00'))
# Query did return data for (-35.183495, 148.507438, Timestamp('2025-03-24 00:00:00'))
# Query did return data for (-35.183709, 148.506767, Timestamp('2025-03-24 00:00:00'))
# Query did return data for (-35.189482, 148.409874, Timestamp('2025-03-24 00:00:00'))
# Query did return data for (-35.189138, 148.409675, Timestamp('2025-03-24 00:00:00'))
# Query did return data for (-35.183637, 148.507044, Timestamp('2025-03-24 00:00:00'))
# Query did return data for (-35.183521, 148.507304, Timestamp('2025-03-24 00:00:00'))
# Query did return data for (-35.183653, 148.506892, Timestamp('2025-03-24 00:00:00'))
# Query did return data for (-35.1836, 148.50718, Timestamp('2025-03-24 00:00:00'))
# Query did return data for (-33.90741358, 149.904488, Timestamp('2025-03-26 00:00:00'))
# Masking removed all data for (-33.90741358, 149.904488, Timestamp('2025-03-26 00:00:00'))
# Query did return data for (-33.90737223, 149.9039199, Timestamp('2025-03-26 00:00:00'))
# Masking removed all data for (-33.90737223, 149.9039199, Timestamp('2025-03-26 00:00:00'))
# Query did return data for (-33.9074067, 149.9042387, Timestamp('2025-03-26 00:00:00'))
# Masking removed all data for (-33.9074067, 149.9042387, Timestamp('2025-03-26 00:00:00'))
# Query did return data for (-33.90749407, 149.9046765, Timestamp('2025-03-26 00:00:00'))
# Masking removed all data for (-33.90749407, 149.9046765, Timestamp('2025-03-26 00:00:00'))
# Query did return data for (-33.90739635, 149.9046849, Timestamp('2025-03-26 00:00:00'))
# Masking removed all data for (-33.90739635, 149.9046849, Timestamp('2025-03-26 00:00:00'))
# Query did return data for (-33.90748213, 149.9041114, Timestamp('2025-03-26 00:00:00'))
# Masking removed all data for (-33.90748213, 149.9041114, Timestamp('2025-03-26 00:00:00'))
# Query did return data for (-30.92654883, 153.0531396, Timestamp('2025-04-07 00:00:00'))
# Query did return data for (-29.81707885, 153.2577779, Timestamp('2025-04-28 00:00:00'))
